# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
sales = pd.read_csv('/home/weiliang/Downloads/sales.csv')

# %%
sales.head()
# Out:
#      month    sales
# 0  2008-01  7615449
# 1  2008-02  8568396
# 2  2008-03  8819950
# 3  2008-04  9747502
# 4  2008-05  8009360

# %%
year_sales = {}

# %%
sales[sales['month'] >= '2019-01']
# Out:
#        month     sales
# 132  2019-01  36240314
# 133  2019-02  38095216
# 134  2019-03  36987206
# 135  2019-04  36233414
# 136  2019-05  32115609
# 137  2019-06  29733707
# 138  2019-07  35643695
# 139  2019-08  34450755
# 140  2019-09  34044162
# 141  2019-10  28305755

# %%
years = range(2008, 2019 + 1)

# %%
sales[sales['month'].str.contains('2018')]
# Out:
#        month     sales
# 120  2018-01  37558740
# 121  2018-02  40988743
# 122  2018-03  35877543
# 123  2018-04  32794664
# 124  2018-05  34433962
# 125  2018-06  31099590
# 126  2018-07  31796964
# 127  2018-08  35253013
# 128  2018-09  30388959
# 129  2018-10  34725977
# 130  2018-11  35642380
# 131  2018-12  36512564

# %%
f, axes = plt.subplots(12, figsize=(20,35), sharex=True)
#f, axes = plt.subplots(12, 1, sharey=True)
for i, year in enumerate(years):
    year_sales = sales[sales['month'].str.contains(str(year))]
    months = [m.split('-')[1] for m in year_sales.month.values]
    axes[i].set_title(year)
    axes[i].plot(months, year_sales.sales.values)
